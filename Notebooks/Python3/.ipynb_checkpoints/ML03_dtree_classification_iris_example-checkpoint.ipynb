# %% [markdown]
# <h1>Decision Tree</h1>

# %% [markdown]
# <p>In this tutorial we will see how to use a decision tree for classificatino using the iris dataset.<br>
# Visualization of both the result and the decision tree itself are also provided.</p>
# <p>As usual we start by importing all necessary packages ...</p>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline
#%matplotlib nbagg  #uncomment this line for interactive figures

# %% [markdown]
# <p>... and the iris dataset.</p>

# %%
from sklearn.datasets import load_iris
iris = load_iris()
X = iris.data[:,0:3:2]
y = iris.target

# %% [markdown]
# <p>As for the example for the k-Nearest Neighbor method we only keep two features of the whole dataset.</p>
# <p>Then we can apply a decision tree classification, constraining the maximum depth of the tree to be 4 :</p>

# %%
from sklearn import tree
dtr = tree.DecisionTreeClassifier(max_depth=4)
dtr.fit(X,y)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=4,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best')

# %% [markdown]
# <p>In order to visualize the classification result we are going to ask the predicted class for a collection of points mapping the features space.</p>

# %%
xx,yy = np.meshgrid(np.linspace(0.0,10.0,201),np.linspace(0.0,10.0,201))
pred = dtr.predict(np.c_[xx.ravel(),yy.ravel()])
Z = pred.reshape(np.shape(xx))

# %%
plt.figure(figsize=(9,7))
plt.contourf(xx,yy,Z,alpha=0.4)
plt.scatter(X.T[0],X.T[1],c=y)
plt.axis('scaled')
plt.xlabel('Sepal Length')
plt.ylabel('Petal Length')
plt.xlim(2.0,10.0)
plt.ylim(0.0,8.0)
# Out:
# (0.0, 8.0)

# %% [markdown]
# <p>Due to the nature of the decision tree we notice that decision borders are "square" and parallel to features axes.</p>

# %% [markdown]
# <p>We can visualize the decision by using the following lines :<br>
# (requires "GraphViz" and "pydotplus" to be installed on the machine)</p>

# %%
import pydotplus
from sklearn.externals.six import StringIO
from IPython.display import Image  

dot_data = StringIO()
f = tree.export_graphviz(dtr,out_file=dot_data,
                         feature_names=iris.feature_names,
                         class_names=iris.target_names,
                         filled=True,rounded=True)
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())

Image(graph.create_png())

# %% [markdown]
# <p>Or we can export it as a pdf file</p>

# %%
graph.write_pdf('iris.pdf')
# Out:
# True

# %% [markdown]
# <p>Have a look at the scikit documentation :<br>
# http://scikit-learn.org/stable/modules/generated/sklearn.tree.DecisionTreeClassifier.html <br>
# and try to play with the different parameters.</p>
# <ul>
# <li> Does it change the classification ? </li>
# <li> Is it faster ? (use the command " %timeit ") </li>
# <li> Any differences ? </li>
# </ul>
